# %% [markdown]
# # SerpAPI Tool Helper

# %% [markdown]
# This notebook provides a quick rundown of how we construct an async SerpAPI tool. Let's start by query SerpAPI synchronously via their Python SDK:

# %%
from serpapi import GoogleSearch
from getpass import getpass

SERPAPI_API_KEY = getpass("Enter your SerpAPI API key: ")

params = {
    "api_key": SERPAPI_API_KEY,
    "engine": "google",
    "q": "latest news in the world",
}

search = GoogleSearch(params)
results = search.get_dict()

print(results)
# Out:
# {'search_metadata': {'id': '6961451bad9ecf8b7d138bcb', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/12d965d97ad3b970/6961451bad9ecf8b7d138bcb.json', 'pixel_position_endpoint': 'https://serpapi.com/searches/12d965d97ad3b970/6961451bad9ecf8b7d138bcb.json_with_pixel_position', 'created_at': '2026-01-09 18:12:43 UTC', 'processed_at': '2026-01-09 18:12:43 UTC', 'google_url': 'https://www.google.com/search?q=latest+news+in+the+world&oq=latest+news+in+the+world&sourceid=chrome&ie=UTF-8', 'raw_html_file': 'https://serpapi.com/searches/12d965d97ad3b970/6961451bad9ecf8b7d138bcb.html', 'total_time_taken': 1.41}, 'search_parameters': {'engine': 'google', 'q': 'latest news in the world', 'google_domain': 'google.com', 'device': 'desktop'}, 'search_information': {'query_displayed': 'latest news in the world', 'total_results': 4460000000, 'time_taken_displayed': 0.6, 'organic_results_state': 'Results for exact spelling'}, 'inline_videos': [{'position': 1, 'title': "Trump Speech Today LIVE: 'World Will Die If...': Trump's ...", 'link': 'https://www.youtube.com/watch?v=nMYQev9hvs4', 'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSgxJidBgVYyJg94vu80WGwikhJu54aXTuL0D8cVMD0rJAe2jJZfEkyGw&s', 'channel': 'Times Of India', 'platform': 'YouTube'}, {'position': 2, 'title': 'ABC World News Tonight with David Muir Full Broadcast - Jan ...', 'link': 'https://www.youtube.com/watch?v=0osognutD_8', 'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRthZwstZCHebZjLFU-ejA2U4tvjwsDp1e6v1o45DOGHnrq2kUljpTVig&s', 'channel': 'ABC News', 'duration': '20:24', 'platform': 'YouTube'}, {'position': 3, 'title': 'Colombia\'s president says he\'ll go to White House "to stop a ...', 'link': 'https://www.cbsnews.com/video/colombias-president-says-hell-go-to-white-house-to-stop-a-world-war/', 'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSS2mJU91xSuKevKFU3Z2YdxQgKzQostAVJpzWYWV9i0RTscnk8HQj3eQ&s', 'channel': 'CBS News', 'duration': '2:42', 'platform': 'CBS News'}], 'related_questions': [{'question': 'What are the top 10 news headlines of today?', 'type': 'featured_snippet', 'title': 'Is DMK–Congress alliance under strain? Seat-sharing, power pact, and the Vijay question', 'link': 'https://indianexpress.com/', 'list': ['Medical Commission withdraws MBBS nod to Vaishno Devi college amid row over admission to Muslims.', "Demolition drive near Delhi's Faiz Elahi mosque turns violent amid stone pelting, tear gas action."], 'source_logo': 'https://serpapi.com/searches/6961451bad9ecf8b7d138bcb/images/005abd773d04d1ae77e5386f55bdc4c7f0251d42b0ee598b3e24973730f35da0.png', 'next_page_token': '...', 'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%...%3D'}, {'question': 'What are the biggest news right now?', 'type': 'ai_overview', 'text_blocks': [{'type': 'paragraph', 'snippet': "Top news includes ongoing political tensions in the U.S. (Trump's legal issues, ICE shooting fallout in Minneapolis, Senate votes on war powers), escalating international conflicts (Russia/Ukraine, unrest in Iran, events in Venezuela after Maduro's removal), and significant events like severe weather in the UK (Storm Goretti), major health/dietary guideline shifts, and crypto market spikes (Bitcoin).", 'snippet_highlighted_words': ["ongoing political tensions in the U.S. (Trump's legal issues, ICE shooting fallout in Minneapolis, Senate votes on war powers), escalating international conflicts (Russia/Ukraine, unrest in Iran, events in Venezuela after Maduro's removal), and significant events like severe weather in the UK (Storm Goretti), major health/dietary guideline shifts, and crypto market spikes (Bitcoin)"], 'reference_indexes': [1, 3, 4, 5, 6]}, {'type': 'paragraph', 'snippet': 'U.S. News'}, {'type': 'list', 'list': [{'title': 'Politics & Legal:', 'snippet': "Trump seeks millions from Fani Willis' office; Senate advances measure t ...

# %% [markdown]
# Our results are provided in the `"organic_results"` key:

# %%
results["organic_results"]
# Out:
# [{'position': 1,
#   'title': 'World | Latest News & Updates',
#   'link': 'https://www.bbc.com/news/world',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.bbc.com/news/world&ved=2ahUKEwjA2vfFh_-RAxUYDzQIHZefAwAQFnoECBgQAQ',
#   'displayed_link': 'https://www.bbc.com › news › world',
#   'favicon': 'https://serpapi.com/searches/6961451bad9ecf8b7d138bcb/images/a1e5f2d48cb5e598291b88bdfff01798cff16e6d023b0c62d12765cd24da488e.png',
#   'snippet': 'World · Huge anti-government protests in Tehran and other Iranian cities, videos show · One dead, dozens trapped after giant landfill collapses in Philippines.',
#   'snippet_highlighted_words': ['Huge anti-government protests in Tehran and other Iranian cities'],
#   'source': 'BBC'},
#  {'position': 2,
#   'title': 'World news - breaking news, video, headlines and opinion',
#   'link': 'https://www.cnn.com/world',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.cnn.com/world&ved=2ahUKEwjA2vfFh_-RAxUYDzQIHZefAwAQFnoECBkQAQ',
#   'displayed_link': 'https://www.cnn.com › world',
#   'favicon': 'https://serpapi.com/searches/6961451bad9ecf8b7d138bcb/images/a1e5f2d48cb5e598291b88bdfff0179824154abd8473996c73264a5fae32e530.png',
#   'snippet': 'World · Anti-government protests spread in Iran as authorities cut communications · Russia strikes western Ukraine with Oreshnik ballistic missile, one of its ...',
#   'snippet_highlighted_words': ['Anti-government protests spread in Iran as authorities cut communications'],
#   'source': 'CNN'},
#  {'position': 3,
#   'title': 'World News | Latest Top Stories',
#   'link': 'https://www.reuters.com/world/',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.reuters.com/world/&ved=2ahUKEwjA2vfFh_-RAxUYDzQIHZefAwAQFnoECEAQAQ',
#   'displayed_link': 'https://www.reuters.com › world',
#   'favicon': 'https://serpapi.com/searches/6961451bad9ecf8b7d138bcb/images/a1e5f2d48cb5e598291b88bdfff01798ac84368b0b93492f9b036da37cd34117.png',
#   'snippet': 'World · 17 hours ago. Iran shuts off internet as protests blaze across country · 17 hours ago. Mercosur bloc to sign EU trade deal on January 17 · 17 hours ago.',
#   'snippet_highlighted_words': ['Iran shuts off internet as protests blaze across country'],
#   'source': 'Reuters'},
#  {'position': 4,
#   'title': 'Breaking News, World News and Video from Al Jazeera',
#   'link': 'https://www.aljazeera.com/',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.aljazeera.com/&ved=2ahUKEwjA2vfFh_-RAxUYDzQIHZefAwAQFnoECD0QAQ',
#   'displayed_link': 'https://www.aljazeera.com',
#   'favicon': 'https://serpapi.com/searches/6961451bad9ecf8b7d138bcb/images/a1e5f2d48cb5e598291b88bdfff01798eca50e721d755ae60db04720906526cb.png',
#   'snippet': "Syria's army warns SDF fighters of imminent attacks in Aleppo · Dozens of shelters opened to support 140,000 displaced civilians · Photos: Civilians leave ...",
#   'snippet_highlighted_words': ["Syria's army warns SDF fighters of imminent attacks in Aleppo"],
#   'source': 'Al Jazeera'},
#  {'position': 5,
#   'title': 'Latest news from around the world',
#   'link': 'https://www.theguardian.com/world',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.theguardian.com/world&ved=2ahUKEwjA2vfFh_-RAxUYDzQIHZefAwAQFnoECD8QAQ',
#   'displayed_link': 'https://www.theguardian.com › world',
#   'favicon': 'https://serpapi.com/searches/6961451bad9ecf8b7d138bcb/images/a1e5f2d48cb5e598291b88bdfff01798de4d44098c05bb33b094d324f3d4563e.png',
#   'snippet': 'Americas · EU states back controversial Mercosur deal with Latin American countries · US military forces seize fifth tanker in effort to control Venezuelan oil.',
#   'snippet_highlighted_words': ['EU states back controversial Mercosur deal with Latin American countries'],
#   'source': 'The Guardian'},
#  {'position': 6,
#   'title': 'Google News',
#   'link': 'https://news.google.com/',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://news.google.com/&ved=2ahUKEwjA2vfFh_-RAxUYDzQIHZefAwAQFnoECDwQAQ',
#   'displayed_link': 'https://news.google.com',
#   'favicon': 'https://serpapi.com/searches/6961451bad9ecf8b7d138bcb/images/a1e5f2d48cb5e598291b88bdfff017982ec7e93b5df255ee4f8469eace0e1e4d.png',
#   'snippet': "Second night of US protests over ICE shooting of woman in Minneapolis · Iran's supreme leader says protesters are 'ruining their own streets' to please Trump.",
#   'snippet_highlighted_words': ['Second night of US protests over ICE shooting of woman in Minneapolis'],
#   'source': 'Google News'},
#  {'position': 7,
#   'title': 'ABC News - Breaking News, Latest News and Videos',
#   'link': 'https://abcnews.go.com/',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://abcnews.go.com/&ved=2ahUKEwjA2vfFh_-RAxUYDzQIHZefAwAQFnoECEQQAQ',
#   'displayed_link': 'https://abcnews.go.com',
#   'favicon': 'https://serpapi.com/searches/6961451bad9ecf8b7d138bcb/images/a1e5f2d48cb5e598291b88bdfff0179837cd0be858cc2356d001ec913a18fba2.png',
#   'snippet': "Iran's new wave of protests prompts hospital raids, internet access cut · Sudan marks 1,000 days of bloody civil war · UN cites 'widespread repression' in Uganda ...",
#   'snippet_highlighted_words': ["Iran's new wave of protests prompts hospital raids, internet access cut"],
#   'sitelinks': {'inline': [{'title': 'International',
#      'link': 'https://abcnews.go.com/International'},
#     {'title': 'U.S.', 'link': 'https://abcnews.go.com/US'},
#     {'title': 'Politics', 'link': 'https://abcnews.go.com/Politics'},
#     {'title': 'Covid-19',
#      'link': 'https://abcnews.go.com/Health/Coronavirus'}]},
#   'source': 'go.com'},
#  {'position': 8,
#   'title': 'Fox News - Breaking News Updates | Latest News Headlines ...',
#   'link': 'https://www.foxnews.com/',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.foxnews.com/&ved=2ahUKEwjA2vfFh_-RAxUYDzQIHZefAwAQFnoECD4QAQ',
#   'displayed_link': 'https://www.foxnews.com',
#   'favicon': 'https://serpapi.com/searches/6961451bad9ecf8b7d138bcb/images/a1e5f2d48cb5e598291b88bdfff01798b5d03732aab24a2b17cbe61268f38999.png',
#   'snippet': "Trump discusses expansion of drug cartel crackdown, issues grim warning to Iran · Jonathan Turley slams Minneapolis mayor's 'reckless' response to ICE shooting.",
#   'snippet_highlighted_words': ['Trump discusses expansion of drug cartel crackdown, issues grim warning to Iran'],
#   'source': 'Fox News'}]

# %% [markdown]
# We reformat this to extract only the most relevant information, such as the the title, source, link, and snippet. Let's use pydantic `BaseModel` to define this structure.

# %%
from pydantic import BaseModel

class Article(BaseModel):
    title: str
    source: str
    link: str
    snippet: str

    @classmethod
    def from_serpapi_result(cls, result: dict) -> "Article":
        return cls(
            title=result["title"],
            source=result["source"],
            link=result["link"],
            snippet=result["snippet"],
        )

# %%
articles = [Article.from_serpapi_result(result) for result in results["organic_results"]]

# %% [markdown]
# ## Using Async

# %% [markdown]
# All of this works, but it unfortunately is not async and the SerpAPI SDK does not support async either, so we much query the API directly using the `aiohttp` library.

# %%
import aiohttp

async with aiohttp.ClientSession() as session:
    async with session.get(
        "https://serpapi.com/search",
        params=params
    ) as response:
        results = await response.json()

results["organic_results"]
# Out:
# [{'position': 1,
#   'title': 'World | Latest News & Updates',
#   'link': 'https://www.bbc.com/news/world',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.bbc.com/news/world&ved=2ahUKEwjA2vfFh_-RAxUYDzQIHZefAwAQFnoECBgQAQ',
#   'displayed_link': 'https://www.bbc.com › news › world',
#   'favicon': 'https://serpapi.com/searches/6961451bad9ecf8b7d138bcb/images/a1e5f2d48cb5e598291b88bdfff01798cff16e6d023b0c62d12765cd24da488e.png',
#   'snippet': 'World · Huge anti-government protests in Tehran and other Iranian cities, videos show · One dead, dozens trapped after giant landfill collapses in Philippines.',
#   'snippet_highlighted_words': ['Huge anti-government protests in Tehran and other Iranian cities'],
#   'source': 'BBC'},
#  {'position': 2,
#   'title': 'World news - breaking news, video, headlines and opinion',
#   'link': 'https://www.cnn.com/world',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.cnn.com/world&ved=2ahUKEwjA2vfFh_-RAxUYDzQIHZefAwAQFnoECBkQAQ',
#   'displayed_link': 'https://www.cnn.com › world',
#   'favicon': 'https://serpapi.com/searches/6961451bad9ecf8b7d138bcb/images/a1e5f2d48cb5e598291b88bdfff0179824154abd8473996c73264a5fae32e530.png',
#   'snippet': 'World · Anti-government protests spread in Iran as authorities cut communications · Russia strikes western Ukraine with Oreshnik ballistic missile, one of its ...',
#   'snippet_highlighted_words': ['Anti-government protests spread in Iran as authorities cut communications'],
#   'source': 'CNN'},
#  {'position': 3,
#   'title': 'World News | Latest Top Stories',
#   'link': 'https://www.reuters.com/world/',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.reuters.com/world/&ved=2ahUKEwjA2vfFh_-RAxUYDzQIHZefAwAQFnoECEAQAQ',
#   'displayed_link': 'https://www.reuters.com › world',
#   'favicon': 'https://serpapi.com/searches/6961451bad9ecf8b7d138bcb/images/a1e5f2d48cb5e598291b88bdfff01798ac84368b0b93492f9b036da37cd34117.png',
#   'snippet': 'World · 17 hours ago. Iran shuts off internet as protests blaze across country · 17 hours ago. Mercosur bloc to sign EU trade deal on January 17 · 17 hours ago.',
#   'snippet_highlighted_words': ['Iran shuts off internet as protests blaze across country'],
#   'source': 'Reuters'},
#  {'position': 4,
#   'title': 'Breaking News, World News and Video from Al Jazeera',
#   'link': 'https://www.aljazeera.com/',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.aljazeera.com/&ved=2ahUKEwjA2vfFh_-RAxUYDzQIHZefAwAQFnoECD0QAQ',
#   'displayed_link': 'https://www.aljazeera.com',
#   'favicon': 'https://serpapi.com/searches/6961451bad9ecf8b7d138bcb/images/a1e5f2d48cb5e598291b88bdfff01798eca50e721d755ae60db04720906526cb.png',
#   'snippet': "Syria's army warns SDF fighters of imminent attacks in Aleppo · Dozens of shelters opened to support 140,000 displaced civilians · Photos: Civilians leave ...",
#   'snippet_highlighted_words': ["Syria's army warns SDF fighters of imminent attacks in Aleppo"],
#   'source': 'Al Jazeera'},
#  {'position': 5,
#   'title': 'Latest news from around the world',
#   'link': 'https://www.theguardian.com/world',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.theguardian.com/world&ved=2ahUKEwjA2vfFh_-RAxUYDzQIHZefAwAQFnoECD8QAQ',
#   'displayed_link': 'https://www.theguardian.com › world',
#   'favicon': 'https://serpapi.com/searches/6961451bad9ecf8b7d138bcb/images/a1e5f2d48cb5e598291b88bdfff01798de4d44098c05bb33b094d324f3d4563e.png',
#   'snippet': 'Americas · EU states back controversial Mercosur deal with Latin American countries · US military forces seize fifth tanker in effort to control Venezuelan oil.',
#   'snippet_highlighted_words': ['EU states back controversial Mercosur deal with Latin American countries'],
#   'source': 'The Guardian'},
#  {'position': 6,
#   'title': 'Google News',
#   'link': 'https://news.google.com/',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://news.google.com/&ved=2ahUKEwjA2vfFh_-RAxUYDzQIHZefAwAQFnoECDwQAQ',
#   'displayed_link': 'https://news.google.com',
#   'favicon': 'https://serpapi.com/searches/6961451bad9ecf8b7d138bcb/images/a1e5f2d48cb5e598291b88bdfff017982ec7e93b5df255ee4f8469eace0e1e4d.png',
#   'snippet': "Second night of US protests over ICE shooting of woman in Minneapolis · Iran's supreme leader says protesters are 'ruining their own streets' to please Trump.",
#   'snippet_highlighted_words': ['Second night of US protests over ICE shooting of woman in Minneapolis'],
#   'source': 'Google News'},
#  {'position': 7,
#   'title': 'ABC News - Breaking News, Latest News and Videos',
#   'link': 'https://abcnews.go.com/',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://abcnews.go.com/&ved=2ahUKEwjA2vfFh_-RAxUYDzQIHZefAwAQFnoECEQQAQ',
#   'displayed_link': 'https://abcnews.go.com',
#   'favicon': 'https://serpapi.com/searches/6961451bad9ecf8b7d138bcb/images/a1e5f2d48cb5e598291b88bdfff0179837cd0be858cc2356d001ec913a18fba2.png',
#   'snippet': "Iran's new wave of protests prompts hospital raids, internet access cut · Sudan marks 1,000 days of bloody civil war · UN cites 'widespread repression' in Uganda ...",
#   'snippet_highlighted_words': ["Iran's new wave of protests prompts hospital raids, internet access cut"],
#   'sitelinks': {'inline': [{'title': 'International',
#      'link': 'https://abcnews.go.com/International'},
#     {'title': 'U.S.', 'link': 'https://abcnews.go.com/US'},
#     {'title': 'Politics', 'link': 'https://abcnews.go.com/Politics'},
#     {'title': 'Covid-19',
#      'link': 'https://abcnews.go.com/Health/Coronavirus'}]},
#   'source': 'go.com'},
#  {'position': 8,
#   'title': 'Fox News - Breaking News Updates | Latest News Headlines ...',
#   'link': 'https://www.foxnews.com/',
#   'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.foxnews.com/&ved=2ahUKEwjA2vfFh_-RAxUYDzQIHZefAwAQFnoECD4QAQ',
#   'displayed_link': 'https://www.foxnews.com',
#   'favicon': 'https://serpapi.com/searches/6961451bad9ecf8b7d138bcb/images/a1e5f2d48cb5e598291b88bdfff01798b5d03732aab24a2b17cbe61268f38999.png',
#   'snippet': "Trump discusses expansion of drug cartel crackdown, issues grim warning to Iran · Jonathan Turley slams Minneapolis mayor's 'reckless' response to ICE shooting.",
#   'snippet_highlighted_words': ['Trump discusses expansion of drug cartel crackdown, issues grim warning to Iran'],
#   'source': 'Fox News'}]

# %% [markdown]
# With that, we have all we need to build a fully async serpapi tool.

# %%
from langchain_core.tools import tool

@tool
async def serpapi(query: str) -> list[Article]:
    """Use this tool to search the web."""
    params = {
        "api_key": SERPAPI_API_KEY,
        "engine": "google",
        "q": query,
    }
    async with aiohttp.ClientSession() as session:
        async with session.get(
            "https://serpapi.com/search",
            params=params
        ) as response:
            results = await response.json()
    return [Article.from_serpapi_result(result) for result in results["organic_results"]]

# %% [markdown]
# Note that because this tool is async, we cannot use `tool.func` to call it as before:

# %%
serpapi.func

# %% [markdown]
# Instead, we use `tool.coroutine`:

# %%
serpapi.coroutine
# Out:
# <function __main__.serpapi(query: str) -> list[__main__.Article]>

# %% [markdown]
# ---
