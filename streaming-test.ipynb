# %% [markdown]
# ## Test Streaming API

# %% [markdown]
# This notebook covers hitting the API `/invoke` endpoint and streaming the code to our terminal.

# %%
import requests

def get_stream(query: str):
    localsession = requests.Session()
    with localsession.post(
        f"http://localhost:8000/invoke?content={query}",
        stream=True,
        headers={"Accept": "text/event-stream"}
    ) as response:
        for token in response.iter_content(decode_unicode=True):
            if token:  # Skip empty lines
                print(token, end="", flush=True)

# %% [markdown]
# We can test with the simple `add` tool first:

# %%
get_stream("what is 5+5")
# Out:
# <step><step_name>final_answer</step_name>{"answer":"10","tools_used":["add"]}

# %% [markdown]
# Now let's try the `serpapi` tool:

# %%
get_stream("tell me about the latest news in the world")
# Out:
# <step><step_name>serpapi</step_name>{"query":"latest news in the world"}</step><step><step_name>final_answer</step_name>{"answer":"The latest news in the world includes anti-government protests in Iran, a giant landfill collapse in the Philippines, and Russia striking western Ukraine with a ballistic missile. Additionally, there are reports of protests in the US over an ICE shooting, and Sudan marking 1,000 days of bloody civil war. For more information, you can check out the latest news from reputable sources such as BBC, CNN, and Al Jazeera.","tools_used":["serpapi"]}

# %%
get_stream(
    "how cold is it in oslo right now, what is 5*5, and what "
    "do you get when multiplying those two numbers together?"
)
# Out:
# <step><step_name>serpapi</step_name>{"query":"Oslo temperature right now"}<step><step_name>multiply</step_name>{"x":5,"y":5}<step><step_name>multiply</step_name>{"x":25,"y":25}<step><step_name>final_answer</step_name>{"answer":"I will answer once I have the results from the above functions","tools_used":["serpapi","multiply"]}

# %%
get_stream("what is the current date and time in these places: dubai, tokyo, berlin?")
# Out:
# <step><step_name>serpapi</step_name>{"query":"current date and time in Dubai, Tokyo, Berlin"}</step><step><step_name>serpapi</step_name>{"query":"current date and time in Dubai"}<step><step_name>serpapi</step_name>{"query":"current date and time in Tokyo"}<step><step_name>serpapi</step_name>{"query":"current date and time in Berlin"}</step><step><step_name>final_answer</step_name>{"answer":"The current date and time in Dubai is Friday, January 9, 2026 at 6:31 pm, in Tokyo is Saturday, January 10, 2026 at 2:24 am, and in Berlin is Friday, January 9, 2026 at 12:43 am. The result of 5*5 is 25. Multiplying 25 by the current temperature in Oslo (which is not provided) is not possible without the current temperature. ","tools_used":["serpapi"]}

# %% [markdown]
# ---
